# %%
import sys
sys.path.insert(0, '..')
from utils.New_Utils import main, make_cfg
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("../../data/Final_Energy_Dataset_with_weather.csv.xz")
df.head(1)
# Out:
#      price  emissions                 Date  load_1  load_2  load_3  load_4  \
# 0  0.21846     1.0662  2010-07-01 00:30:00   1.553   0.085   2.698   0.075
#
#    load_5  load_6  load_7  ...  pv_297  pv_298  pv_299  pv_300  temp  dwpt  \
# 0   1.917   0.044   1.831  ...     0.0     0.0     0.0     0.0   0.7  -0.6
#
#    rhum   wdir  wspd    pres
# 0  91.0  160.0   5.4  1022.0
#
# [1 rows x 610 columns]

# %%
# Local Learning Ausgrid Prosumption
cfg = make_cfg(
    file_path="../../data/Final_Energy_Dataset_with_weather.csv.xz",
    columns="prosumption", nr_buildings=20, cluster_size=20, results_dir="../Results/LocalLearning",
    rounds=3,
    experiment_name=f"LL_Prosumption_Ausgrid_Allmodels",
    attack_enabled=False, use_federated=False, plot=False,
     models_to_run=["mlp", "cnn", "lstm", "transformer", "softdense", "softlstm"],
    plot_month_predictions=True,  use_weather=False, 
)
cfg["model_hyperparams"]["mlp"]["dense_units"] = 8
cfg["model_hyperparams"]["mlp"]["num_layers"] = 4
cfg["model_hyperparams"]["mlp"]["dropout"] = 0.2

combined_all, per_hour = main(cfg)
# Out:
# Saved -> ../Results/LocalLearning\LL_Prosumption_Ausgrid_Allmodels_clusters.csv.xz
# c:\Users\rs1044\Documents\GitHub\RuntimeExperimentsRaspberryPi5\04Computational_Efficiency\Scripts\..\utils\New_Utils.py:180: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"prosumption_{idx}"] = df[load_col] - df[pv_col]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 15
#      12 cfg["model_hyperparams"]["mlp"]["num_layers"] = 4
#      13 cfg["model_hyperparams"]["mlp"]["dropout"] = 0.2
# ---> 15 combined_all, per_hour = main(cfg)
#
# File c:\Users\rs1044\Documents\GitHub\RuntimeExperimentsRaspberryPi5\04Computational_Efficiency\Scripts\..\utils\New_Utils.py:2413, in main(cfg)
#    2405 df_array = load_and_prepare_data(
#    2406     file_path,
#    2407     buildings,
#    (...)   2410     weather_cols=weather_cols,
#    2411 )
#    2412 step_minutes = infer_step_minutes_from_index(df_array[0].index)
# -> 2413 X_train, y_train, X_val, y_val, X_test, y_test, y_test_hour, scalers, test_label_index = split_data(
#    2414     df_array, sequence_length=sequence_length, batch_size=train_cfg["batch_size"]
#    2415 )
#    2418 poisoned_building = buildings[0]
#    2419 attack_type, attack_details = "none", "none"
#
# File c:\Users\rs1044\Documents\GitHub\RuntimeExperimentsRaspberryPi5\04Computational_Efficiency\Scripts\..\utils\New_Utils.py:283, in split_data(df_array, sequence_length, batch_size)
#     280 val_seq   = create_sequences(val_df, sequence_length)
#     281 test_seq  = create_sequences(test_df, sequence_length)
# --> 283 X_train[ux], y_train[ux], _   = prepare_data_with_label_time(train_seq, batch_size)
#     284 X_val[ux],   y_val[ux],   _   = prepare_data_with_label_time(val_seq,   batch_size)
#     285 X_test[ux],  y_test[ux],  y_h = prepare_data_with_label_time(test_seq,  batch_size)
#
# File c:\Users\rs1044\Documents\GitHub\RuntimeExperimentsRaspberryPi5\04Computational_Efficiency\Scripts\..\utils\New_Utils.py:137, in prepare_data_with_label_time(sequences, batch_size, sin_idx, cos_idx)
#     131 def prepare_data_with_label_time(sequences: np.ndarray, batch_size: int, sin_idx=1, cos_idx=2):
#     132     """
#     133     Return X, y, y_hour for each sequence (based on the label time step).
#     134     X: seq[:-1,:], y: seq[-1,0], y_hour from seq[-1,sin/cos].
#     135     Trim to full batches for static-batch models.
#     136     """
# --> 137     X = sequences[:, :-1, :].astype('float32')
#     138     y = sequences[:, -1, 0].astype('float32')
#     139     sin = sequences[:, -1, sin_idx]
#
# KeyboardInterrupt:

# %%
# Local Learning Ausgrid PV
cfg = make_cfg(
    file_path="../../data/Final_Energy_Dataset_with_weather.csv.xz",
    columns="pv", nr_buildings=20, cluster_size=20, results_dir="../Results/LocalLearning",
    rounds=3,
    experiment_name=f"LL_PV_Ausgrid_Allmodels",
    attack_enabled=False, use_federated=False, plot=False,
     models_to_run=["mlp", "cnn", "lstm", "transformer", "softdense", "softlstm"],
    plot_month_predictions=True,  use_weather=False, 
)
cfg["model_hyperparams"]["mlp"]["dense_units"] = 8
cfg["model_hyperparams"]["mlp"]["num_layers"] = 4
cfg["model_hyperparams"]["mlp"]["dropout"] = 0.2

combined_all, per_hour = main(cfg)

# %%
# Local Learning Ausgrid Load
cfg = make_cfg(
    file_path="../../data/Final_Energy_Dataset_with_weather.csv.xz",
    columns="load", nr_buildings=20, cluster_size=20, results_dir="../Results/LocalLearning",
    rounds=3,
    experiment_name=f"LL_Load_Ausgrid_Allmodels",
    attack_enabled=False, use_federated=False, plot=False,
     models_to_run=["mlp", "cnn", "lstm", "transformer", "softdense", "softlstm"],
    plot_month_predictions=True,  use_weather=False, 
)
cfg["model_hyperparams"]["mlp"]["dense_units"] = 8
cfg["model_hyperparams"]["mlp"]["num_layers"] = 4
cfg["model_hyperparams"]["mlp"]["dropout"] = 0.2

combined_all, per_hour = main(cfg)

# %%
# Local Learning Ausgrid Load
cfg = make_cfg(
    file_path="../../data/Spark_Dataset_30m_2024_10loads.csv.xz",
    columns="load", nr_buildings=10, cluster_size=10, results_dir="../Results/LocalLearning",
    rounds=3,
    experiment_name=f"LL_Load_SPARK_Allmodels",
    attack_enabled=False, use_federated=False, plot=False,
     models_to_run=["mlp", "cnn", "lstm", "transformer", "softdense", "softlstm"],
    plot_month_predictions=True,  use_weather=False, 
)
cfg["model_hyperparams"]["mlp"]["dense_units"] = 8
cfg["model_hyperparams"]["mlp"]["num_layers"] = 4
cfg["model_hyperparams"]["mlp"]["dropout"] = 0.2

combined_all, per_hour = main(cfg)
