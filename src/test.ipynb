# %%
import pandas as pd

# %%
ausgrid = pd.read_csv("../data/Final_Energy_Dataset_with_weather.csv.xz")
ausgrid
# Out:
#          price  emissions                 Date  load_1  load_2  load_3  \
# 0      0.21846   1.066200  2010-07-01 00:30:00   1.553   0.085   2.698
# 1      0.21836   1.064706  2010-07-01 01:00:00   1.715   0.142   2.684
# 2      0.22172   1.061807  2010-07-01 01:30:00   1.339   0.082   1.675
# 3      0.22099   1.064542  2010-07-01 02:00:00   0.865   0.119   0.683
# 4      0.21798   1.062929  2010-07-01 02:30:00   0.380   0.105   0.694
# ...        ...        ...                  ...     ...     ...     ...
# 52603  0.23978   1.071594  2013-06-30 22:00:00   0.274   0.303   0.056
# 52604  0.24490   1.078417  2013-06-30 22:30:00   0.509   0.182   0.056
# 52605  0.24237   1.064344  2013-06-30 23:00:00   0.166   0.158   0.065
# 52606  0.24279   1.065842  2013-06-30 23:30:00   0.861   0.131   0.063
# 52607  0.24215   1.066102  2013-07-01 00:00:00   1.687   0.121   0.052
#
#        load_4  load_5  load_6  load_7  ...  pv_297  pv_298  pv_299  pv_300  \
# ...
